# %%
import extcolors
import os
import concurrent.futures
import math
from collections import Counter
from database import (drop_table,conn,cursor,create_table)

table_name = "PopularColors"
drop_table(table_name)
create_table(table_name, "color","total")

def insert_data(color, total):
    query = f"INSERT INTO {table_name} (color, total) VALUES (?, ?)"
    cursor.execute(query, color, total)
    conn.commit()
    
COLORS = {
    "red": ((255, 0, 0), (255, 99, 71)),
    "orange": ((255, 165, 0), (255, 140, 0)),
    "yellow": ((255, 255, 0), (255, 215, 0)),
    "green": ((0, 128, 0), (0, 255, 0)),
    "blue": ((0, 0, 255), (0, 0, 128)),
    "purple": ((128, 0, 128), (218, 112, 214)),
    "pink": ((255, 192, 203), (255, 105, 180)),
    "brown": ((165, 42, 42), (139, 69, 19)),
    "black": ((0, 0, 0), (25, 25, 25)),
    "white": ((255, 255, 255), (245, 245, 245)),
    "gray": ((128, 128, 128), (169, 169, 169)),
    "navy": ((0, 0, 128), (0, 0, 139)),
    "olive": ((128, 128, 0), (107, 142, 35)),
    "silver": ((192, 192, 192), (211, 211, 211)),
    "gold": ((255, 215, 0), (255, 165, 0)),
    "sky blue": ((135, 206, 235), (135, 206, 250)),
    "turquoise": ((64, 224, 208), (0, 245, 255)),
    "indigo": ((75, 0, 130), (138, 43, 226)),
    "violet": ((238, 130, 238), (148, 0, 211)),
    "beige": ((245, 245, 220), (245, 245, 220)),
    "magenta": ((255, 0, 255), (199, 21, 133)),
    "orchid": ((218, 112, 214), (255, 131, 250)),
    "peach": ((255, 218, 185), (255, 229, 180)),
    "salmon": ((250, 128, 114), (255, 99, 71)),
    "tan": ((210, 180, 140), (210, 180, 140))
}

def determine_closest_color(rgb):
    """
    Given an RGB tuple, returns the name of the closest color from the COLORS dictionary.
    """
    min_distance = math.inf
    closest_color = "unknown"
    for color, (min_rgb, max_rgb) in COLORS.items():
        r_distance = rgb[0] - (min_rgb[0] + max_rgb[0]) / 2
        g_distance = rgb[1] - (min_rgb[1] + max_rgb[1]) / 2
        b_distance = rgb[2] - (min_rgb[2] + max_rgb[2]) / 2
        distance = math.sqrt(r_distance ** 2 + g_distance ** 2 + b_distance ** 2)
        if distance < min_distance:
            min_distance = distance
            closest_color = color
    return closest_color

def most_common_colors(img_file):
    """
    Given the name of an image file, returns a list of the three most common colors in the image.
    """
    img_file = os.path.join("imgs", img_file)
    colors = extcolors.extract_from_path(img_file, tolerance=12, limit=12)[0]
    color_counts = Counter(dict(colors)).most_common(4)
    print(f" picture {img_file} is done")
    del color_counts[0]
    return [color[0] for color in color_counts]

def main():
    """
    Main function that processes all the images in the "imgs" directory and prints the count of the closest color for each image.
    """
    img_files = os.listdir("imgs")
    colors_dict = {}
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        futures = [executor.submit(most_common_colors, img_file) for img_file in img_files]
        list_colors = [color for future in concurrent.futures.as_completed(futures) for color in future.result()]
    for rgb in list_colors:
        color = determine_closest_color(rgb)
        if color in colors_dict:
            colors_dict[color] += 1
        else:
            colors_dict[color] = 1
    for color in colors_dict:
        insert_data(color, colors_dict[color])
    print("Data has been saved in database")
if __name__ == '__main__':
    print("Analyse has been started")
    main()
    print("Analysis has ended")
# Out:
# Table 'PopularColors' created
# Analyse has been started
#  picture imgs\zb100.jpg is done
#  picture imgs\zb1.jpg is done
#  picture imgs\zb10.jpg is done
#  picture imgs\zb101.jpg is done
#  picture imgs\zb11.jpg is done
#  picture imgs\zb102.jpg is done
#  picture imgs\zb13.jpg is done
#  picture imgs\zb103.jpg is done
#  picture imgs\zb12.jpg is done
#  picture imgs\zb15.jpg is done
#  picture imgs\zb18.jpg is done
#  picture imgs\zb14.jpg is done
#  picture imgs\zb16.jpg is done
#  picture imgs\zb19.jpg is done
#  picture imgs\zb17.jpg is done
#  picture imgs\zb21.jpg is done
#  picture imgs\zb20.jpg is done
#  picture imgs\zb22.jpg is done
#  picture imgs\zb23.jpg is done
#  picture imgs\zb2.jpg is done
#  picture imgs\zb25.jpg is done
#  picture imgs\zb26.jpg is done
#  picture imgs\zb29.jpg is done
#  picture imgs\zb28.jpg is done
#  picture imgs\zb30.jpg is done
#  picture imgs\zb27.jpg is done
#  picture imgs\zb3.jpg is done
#  picture imgs\zb31.jpg is done
#  picture imgs\zb32.jpg is done
#  picture imgs\zb34.jpg is done
#  picture imgs\zb33.jpg is done
#  picture imgs\zb36.jpg is done
#  picture imgs\zb37.jpg is done
#  picture imgs\zb35.jpg is done
#  picture imgs\zb39.jpg is done
#  picture imgs\zb4.jpg is done
#  picture imgs\zb41.jpg is done
#  picture imgs\zb42.jpg is done
#  picture imgs\zb40.jpg is done
#  picture imgs\zb43.jpg is done
#  picture imgs\zb44.jpg is done
#  picture imgs\zb46.jpg is done
#  picture imgs\zb48.jpg is done
#  picture imgs\zb47.jpg is done
#  picture imgs\zb45.jpg is done
#  picture imgs\zb5.jpg is done
#  picture imgs\zb50.jpg is done
#  picture imgs\zb51.jpg is done picture imgs\zb24.jpg is done
#
#  picture imgs\zb52.jpg is done
#  picture imgs\zb49.jpg is done
#  picture imgs\zb54.jpg is done
#  picture imgs\zb55.jpg is done
#  picture imgs\zb53.jpg is done
#  picture imgs\zb58.jpg is done
#  picture imgs\zb57.jpg is done
#  picture imgs\zb60.jpg is done
#  picture imgs\zb59.jpg is done
#  picture imgs\zb61.jpg is done
#  picture imgs\zb63.jpg is done
#  picture imgs\zb62.jpg is done
#  picture imgs\zb38.jpg is done
#  picture imgs\zb65.jpg is done
#  picture imgs\zb64.jpg is done
#  picture imgs\zb66.jpg is done
#  picture imgs\zb67.jpg is done
#  picture imgs\zb68.jpg is done
#  picture imgs\zb69.jpg is done
#  picture imgs\zb7.jpg is done
#  picture imgs\zb71.jpg is done
#  picture imgs\zb72.jpg is done
#  picture imgs\zb73.jpg is done
#  picture imgs\zb74.jpg is done
#  picture imgs\zb56.jpg is done
#  picture imgs\zb78.jpg is done
#  picture imgs\zb75.jpg is done
#  picture imgs\zb76.jpg is done
#  picture imgs\zb80.jpg is done
#  picture imgs\zb79.jpg is done
#  picture imgs\zb8.jpg is done
#  picture imgs\zb77.jpg is done
#  picture imgs\zb82.jpg is done
#  picture imgs\zb83.jpg is done
#  picture imgs\zb84.jpg is done
#  picture imgs\zb86.jpg is done
#  picture imgs\zb85.jpg is done
#  picture imgs\zb89.jpg is done
#  picture imgs\zb87.jpg is done
#  picture imgs\zb90.jpg is done
#  picture imgs\zb9.jpg is done
#  picture imgs\zb92.jpg is done
#  picture imgs\zb93.jpg is done
#  picture imgs\zb95.jpg is done
#  picture imgs\zb94.jpg is done
#  picture imgs\zb91.jpg is done
#  picture imgs\zb97.jpg is done
#  picture imgs\zb96.jpg is done
#  picture imgs\zb99.jpg is done
#  picture imgs\zb70.jpg is done picture imgs\zb98.jpg is done
#
# Data has been saved in database
# Analysis has ended
